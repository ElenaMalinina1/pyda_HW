# %% [markdown]
# # DataLens #
# ## Задание
# Вопросы по заданию
# Давайте подведём итоги. Мы взялись за первую и очень важную задачу для ритейл-сети — определились с местом размещения её новой точки. В этом нам помог облачный сервис Yandex DataLens. Мы построили удобную карту, визуализировали нужные данные по имеющимся точкам и определились с потенциальной новой.
#
# В рамках ДЗ вам нужно будет развить полученный дашборд, добавив по инструкции следующее:
#
# - чарты-индикаторы с ключевыми метриками;
# - круговую диаграмму;
# - сводную таблицу;
# - публичную общедоступную ссылку.
#
# Доступ по [ссылке]('https://datalens.yandex/7lrtfjekv9hez?state=b6b726cf437')

# %% [markdown]
# # Excel #
# ## Задание
# Вопросы по заданию
# Скачать файл с материалами занятия построить сводную таблицу.
#
# В файле с материалами занятия построить сводную таблицу, в которой отобразить статьи расходов по строкам, а регионы – по столбцам. В значениях нужны суммы расходов.
# Настроить в сводной таблице условное форматирование так, чтобы наименьшая сумма расходов выделялась зеленым, а наибольшая – красным.
# Построить рядом сводную диаграмму, показывающую соотношение расходов в каждом регионе.
#
# Данные в файле  [data.xlsx]('https://docs.google.com/spreadsheets/d/1Dcb3rOpThRIMHM0Oa_MKCfMAzgtEgqY6/edit?usp=sharing&ouid=113908654816751364892&rtpof=true&sd=true)

# %% [markdown]
# # Power BI #
# ## Задание
# [Ссылка на таблицу с набором данных]('https://docs.google.com/spreadsheets/d/15AorjkCEJpDeYW1CvoOIe_Bly2zN8h2B/edit#gid=402457591')
#
# Добавить на страницу отчёта гистограмму с группировкой распределения бюджета по городам и каналам распределения:
#
# на горизонтальной оси нужно отобразить города,
# каналы продвижения должны быть в условных обозначениях.
# Высота столбца соответствует величине бюджета.
# ДЗ займёт не больше 20 минут, но позволит закрепить основной функционал Power BI.
#
# Данные в файле [hw.pbix]('https://docs.google.com/spreadsheets/d/1Dcb3rOpThRIMHM0Oa_MKCfMAzgtEgqY6/edit?usp=sharing&ouid=113908654816751364892&rtpof=true&sd=true')

# %% [markdown]
# # Tableau #
# ## Задание
#
# Зарегистрироваться в Tableau web, создать дашборд, поделиться им в соцсети и прикрепить линк в личном кабинете.
# Создание дашборда для анализа итоговых продаж в Европе.
#
# В качестве практики вам нужно будет сделать дашборд для магазинов Европы.
# [Ссылка]('https://docs.google.com/spreadsheets/d/1HeGeXRH0W7T1jUL-kkmhfE-ETfbkPoOV/edit#gid=142612512') на таблицу с данными для выполнения домашнего задания.
#
# Вам необходимо создать 3-4 визуализации, которые будут использоваться в вашем дашборде. Практику создания визуализаций мы разобрали на вебинаре, а ниже вы увидите несколько примеров, но конечно вы можете придумать и свои собственные варианты.
#
# - Прибыль по подкатегориям
#
# - Динамика прибыли и продаж
#
# - Прибыль и продажи по продуктам
#
# - Прибыль и продажи по регионам
#
# По желанию вы также можете включить анимацию дашбордов
#
# Создайте дашборд и добавьте визуализации
#
# Последний шаг - публикация дашборда
#
# Дашборт [по ссылке]('https://public.tableau.com/app/profile/vixen4263/viz/Book2_16507112986710/Dashboard1?publish=yes')
